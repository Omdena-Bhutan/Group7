# %% [markdown]
# <a href="https://colab.research.google.com/github/Omdena-Bhutan/Group7/blob/main/Visualization_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Visualization with Python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# path = "/content/drive/MyDrive/Data/clean_automobile_data_full.csv"

# %%
path = "https://raw.githubusercontent.com/eparamasari/temp-repo/main/clean_automobile_data_full.csv"

# %% [markdown]
# Download the dataset

# %%
df = pd.read_csv(path)
df.head(20)
# Out:
#     Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0            0          3                122  alfa-romero        std
# 1            1          3                122  alfa-romero        std
# 2            2          1                122  alfa-romero        std
# 3            3          2                164         audi        std
# 4            4          2                164         audi        std
# 5            5          2                122         audi        std
# 6            6          1                158         audi        std
# 7            7          1                122         audi        std
# 8            8          1                158         audi      turbo
# 9            9          2                192          bmw        std
# 10          10          0                192          bmw        std
# 11          11          0                188          bmw        std
# 12          12          0                188          bmw        std
# 13          13          1                122          bmw        std
# 14          14          0                122          bmw        std
# 15          15          0                122          bmw        std
# 16          16          0                122          bmw        std
# 17          17          2                121    chevrolet        std
# 18          18          1                 98    chevrolet        std
# 19          19          0                 81    chevrolet        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two        sedan          rwd           front       101.2  ...
# 10         four        sedan          rwd           front       101.2  ...
# 11          two        sedan          rwd           front       101.2  ...
# 12         four        sedan          rwd           front       101.2  ...
# 13         four        sedan          rwd           front       103.5  ...
# 14         four        sedan          rwd           front       103.5  ...
# 15          two        sedan          rwd           front       103.5  ...
# 16         four        sedan          rwd           front       110.0  ...
# 17          two    hatchback          fwd           front        88.4  ...
# 18          two    hatchback          fwd           front        94.5  ...
# 19         four        sedan          fwd           front        94.5  ...
#
#     horsepower  peak-rpm  city-mpg  highway-mpg    price city-L/100km  \
# 0          111    5000.0        21           27  13495.0    11.190476
# 1          111    5000.0        21           27  16500.0    11.190476
# 2          154    5000.0        19           26  16500.0    12.368421
# 3          102    5500.0        24           30  13950.0     9.791667
# 4          115    5500.0        18           22  17450.0    13.055556
# 5          110    5500.0        19           25  15250.0    12.368421
# 6          110    5500.0        19           25  17710.0    12.368421
# 7          110    5500.0        19           25  18920.0    12.368421
# 8          140    5500.0        17           20  23875.0    13.823529
# 9          101    5800.0        23           29  16430.0    10.217391
# 10         101    5800.0        23           29  16925.0    10.217391
# 11         121    4250.0        21           28  20970.0    11.190476
# 12         121    4250.0        21           28  21105.0    11.190476
# 13         121    4250.0        20           25  24565.0    11.750000
# 14         182    5400.0        16           22  30760.0    14.687500
# 15         182    5400.0        16           22  41315.0    14.687500
# 16         182    5400.0        15           20  36880.0    15.666667
# 17          48    5100.0        47           53   5151.0     5.000000
# 18          70    5400.0        38           43   6295.0     6.184211
# 19          70    5400.0        38           43   6575.0     6.184211
#
#     highway-L/100km horsepower-binned  fuel-type-diesel  fuel-type-gas
# 0          8.703704               Low             False           True
# 1          8.703704               Low             False           True
# 2          9.038462            Medium             False           True
# 3          7.833333               Low             False           True
# 4         10.681818               Low             False           True
# 5          9.400000               Low             False           True
# 6          9.400000               Low             False           True
# 7          9.400000               Low             False           True
# 8         11.750000            Medium             False           True
# 9          8.103448               Low             False           True
# 10         8.103448               Low             False           True
# 11         8.392857            Medium             False           True
# 12         8.392857            Medium             False           True
# 13         9.400000            Medium             False           True
# 14        10.681818            Medium             False           True
# 15        10.681818            Medium             False           True
# 16        11.750000            Medium             False           True
# 17         4.433962               Low             False           True
# 18         5.465116               Low             False           True
# 19         5.465116               Low             False           True
#
# [20 rows x 31 columns]

# %%
df.drop(columns=df.columns[0], axis=1, inplace=True)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    horsepower  peak-rpm  city-mpg highway-mpg    price  city-L/100km  \
# 0         111    5000.0        21          27  13495.0     11.190476
# 1         111    5000.0        21          27  16500.0     11.190476
# 2         154    5000.0        19          26  16500.0     12.368421
# 3         102    5500.0        24          30  13950.0      9.791667
# 4         115    5500.0        18          22  17450.0     13.055556
#
#   highway-L/100km  horsepower-binned  fuel-type-diesel  fuel-type-gas
# 0        8.703704                Low             False           True
# 1        8.703704                Low             False           True
# 2        9.038462             Medium             False           True
# 3        7.833333                Low             False           True
# 4       10.681818                Low             False           True
#
# [5 rows x 30 columns]

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  201.000000
# mean     0.899108  2555.666667   126.875622    3.330692    3.256874
# std      0.040933   517.296727    41.546834    0.268072    0.316048
# min      0.799331  1488.000000    61.000000    2.540000    2.070000
# 25%      0.869565  2169.000000    98.000000    3.150000    3.110000
# 50%      0.904682  2414.000000   120.000000    3.310000    3.290000
# 75%      0.928094  2926.000000   141.000000    3.580000    3.410000
# max      1.000000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.402985  5117.665368   25.179104    30.686567
# std             4.004965   37.365650   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price  city-L/100km  highway-L/100km
# count    201.000000    201.000000       201.000000
# mean   13207.129353      9.944145         8.044957
# std     7947.066342      2.534599         1.840739
# min     5118.000000      4.795918         4.351852
# 25%     7775.000000      7.833333         6.911765
# 50%    10295.000000      9.791667         7.833333
# 75%    16500.000000     12.368421         9.400000
# max    45400.000000     18.076923        14.687500

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'highway-L/100km', 'horsepower-binned',
#        'fuel-type-diesel', 'fuel-type-gas'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Histogram

# %%
# using pandas

df["wheel-base"].plot(kind='hist', title="Wheel base Distribution")
# Out:
# <Axes: title={'center': 'Wheel base Distribution'}, ylabel='Frequency'>

# %%
df["price"].plot(kind='hist', title="Price Distribution", color='red')
# Out:
# <Axes: title={'center': 'Price Distribution'}, ylabel='Frequency'>

# %%
# using matplotlib

# plt.hist(df.horsepower)
plt.hist(df["horsepower"])
# Out:
# (array([44., 45., 48., 24., 14., 16.,  5.,  4.,  0.,  1.]),
#  array([ 48. ,  69.4,  90.8, 112.2, 133.6, 155. , 176.4, 197.8, 219.2,
#         240.6, 262. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["city-L/100km"], color = "limegreen")
# Out:
# (array([0.01123814, 0.05993672, 0.22476271, 0.1573339 , 0.08990508,
#         0.11238136, 0.05619068, 0.01873023, 0.01123814, 0.01123814]),
#  array([ 4.79591837,  6.12401884,  7.45211931,  8.78021978, 10.10832025,
#         11.43642072, 12.76452119, 14.09262166, 15.42072214, 16.74882261,
#         18.07692308]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # **Question 1**
#
# Create a histogram of the column "price"!

# %%
df["price"].plot(kind='hist', title="Price Distribution", color='green')
# Out:
# <Axes: title={'center': 'Price Distribution'}, ylabel='Frequency'>

# %% [markdown]
# ## Boxplot

# %%
# using pandas

df["horsepower"].plot(kind='box', title="Car Horsepower Distribution")
# Out:
# <Axes: title={'center': 'Car Horsepower Distribution'}>

# %%
df[df["horsepower"] > 200]
# Out:
#      symboling  normalized-losses     make aspiration num-of-doors  \
# 46           0                122   jaguar        std          two
# 123          3                122  porsche        std          two
# 124          3                122  porsche        std          two
# 125          3                122  porsche        std          two
#
#       body-style drive-wheels engine-location  wheel-base    length  ...  \
# 46         sedan          rwd           front       102.0  0.921192  ...
# 123      hardtop          rwd            rear        89.5  0.811629  ...
# 124      hardtop          rwd            rear        89.5  0.811629  ...
# 125  convertible          rwd            rear        89.5  0.811629  ...
#
#      horsepower  peak-rpm  city-mpg highway-mpg    price  city-L/100km  \
# 46          262    5000.0        13          17  36000.0     18.076923
# 123         207    5900.0        17          25  32528.0     13.823529
# 124         207    5900.0        17          25  34028.0     13.823529
# 125         207    5900.0        17          25  37028.0     13.823529
#
#     highway-L/100km  horsepower-binned  fuel-type-diesel  fuel-type-gas
# 46        13.823529               High             False           True
# 123        9.400000               High             False           True
# 124        9.400000               High             False           True
# 125        9.400000               High             False           True
#
# [4 rows x 30 columns]

# %%
# using matplotlib
plt.boxplot(df["horsepower"])
plt.title("Horsepower Boxplot")
plt.xlabel("Horsepower")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
# using matplotlib
plt.violinplot(df["horsepower"])
plt.title("Horsepower Violin Plot")
plt.xlabel("Horsepower")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Pie Chart

# %%
print("The body-style column has " + str(len(df['body-style'].value_counts())) + " different values.")
# Out:
# The body-style column has 5 different values.

# %%
df['body-style'].value_counts()
# Out:
# body-style
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
# using pandas
df['body-style'].value_counts().plot(kind='pie')
plt.title("Cars' Body Style")
# Out:
# Text(0.5, 1.0, "Cars' Body Style")

# %%
# using pandas
df['body-style'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(6,7))
plt.title("Cars' Body Style")
# Out:
# Text(0.5, 1.0, "Cars' Body Style")

# %%
# using seaborn and matplotlib
palette_color = sns.color_palette('pastel')
explode = [0, 0, 0, 0.1, 0.1]

style_df = df["body-style"].value_counts()
plt.pie(style_df,
        colors=palette_color,
        labels=style_df.index.tolist(),
        explode=explode,
        autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7979bc2ac140>,
#   <matplotlib.patches.Wedge at 0x7979bc8673b0>,
#   <matplotlib.patches.Wedge at 0x7979bc148050>,
#   <matplotlib.patches.Wedge at 0x7979bc148770>,
#   <matplotlib.patches.Wedge at 0x7979bc148ec0>],
#  [Text(0.1115610486149959, 1.0943281648719103, 'sedan'),
#   Text(-0.717981298737373, -0.8333683787277961, 'hatchback'),
#   Text(0.7436770228683457, -0.8105211198097643, 'wagon'),
#   Text(1.1418460615038513, -0.36903600343075404, 'hardtop'),
#   Text(1.1947271753878765, -0.11236981974581406, 'convertible')],
#  [Text(0.060851481062725025, 0.5969062717483146, '47%'),
#   Text(-0.39162616294765795, -0.45456457021516145, '34%'),
#   Text(0.40564201247364307, -0.4421024289871441, '12%'),
#   Text(0.6660768692105798, -0.2152710020012732, '4%'),
#   Text(0.6969241856429278, -0.06554906151839153, '3%')])

# %% [markdown]
# # **Question 2**
#
# Create a pie chart of the cars' based on their number of doors!

# %%
palette_color = sns.color_palette('tab10')

style_df = df["num-of-doors"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(style_df,
        colors=palette_color,
        labels=style_df.index.tolist(),
        autopct='%.1f%%')
plt.title("Number of Doors")
# Out:
# Text(0.5, 1.0, 'Number of Doors')

# %% [markdown]
# ## Density Plot

# %%
# using seaborn
sns.kdeplot(df.horsepower)
# Out:
# <Axes: xlabel='horsepower', ylabel='Density'>

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# ## Line Chart

# %%
# using matplotlib
x = ["2015", "2016", "2017", "2018", "2019", "2020", "2021", "2022", "2023"]
y = [980, 995, 985, 990, 1000, 875, 950, 975, 1010]

plt.plot(x, y)
plt.title("Average Car Price Over the Years")
plt.xlabel("Year")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ## Bar Chart

# %%
print("The original dataframe has " + str(len(df.columns)) + " columns.")
print("We are now going to select only two of those columns.")
# Out:
# The original dataframe has 30 columns.
# We are now going to select only two of those columns.

# %%
df[["body-style", "price"]].groupby("body-style").mean()
# Out:
#                     price
# body-style
# convertible  21890.500000
# hardtop      22208.500000
# hatchback     9957.441176
# sedan        14459.755319
# wagon        12371.960000

# %%
# using pandas
df[["body-style", "price"]].groupby("body-style").mean().plot(kind='bar')

# modify with matplotlib
plt.title('Body Style vs Price')
plt.ylabel('Price')
plt.xlabel('Body Style')
# Out:
# Text(0.5, 0, 'Body Style')

# %% [markdown]
# # **Question 3**
#
# Create a bar chart of the car data based on their brand/make!

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'highway-L/100km', 'horsepower-binned',
#        'fuel-type-diesel', 'fuel-type-gas'],
#       dtype='object')

# %%
# using pandas
df[["make", "price"]].groupby("make").mean().plot(kind='bar')

# modify with matplotlib
plt.title('Brand vs Price')
plt.ylabel('Price')
plt.xlabel('Brand')
# Out:
# Text(0.5, 0, 'Brand')

# %% [markdown]
# ## Boxplot
#
# To visualize and compare the distribution of price in different car body styles

# %%
# using seaborn
sns.boxplot(x = df["body-style"],
            y = df["price"],
            color = "tan")
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
# add another variable
sns.boxplot(x = df["body-style"],
            y = df["price"],
            hue = df['num-of-doors'])
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'aspiration', 'num-of-doors',
#        'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length',
#        'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
#        'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio',
#        'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price',
#        'city-L/100km', 'highway-L/100km', 'horsepower-binned',
#        'fuel-type-diesel', 'fuel-type-gas'],
#       dtype='object')

# %%
# change color palette
sns.boxplot(x = df["body-style"],
            y = df["price"],
            hue = df['num-of-doors'],
            palette = 'husl')
# Out:
# <Axes: xlabel='body-style', ylabel='price'>

# %% [markdown]
# # **Question 4**
#
# Create boxplots comparing the price of cars with different drive wheels!

# %%
# using seaborn
sns.boxplot(x = df["drive-wheels"],
            y = df["price"],
            hue = df['num-of-doors'],
            palette = 'rocket')
# Out:
# <Axes: xlabel='drive-wheels', ylabel='price'>

# %% [markdown]
# ## Scatter Plot

# %%
# using seaborn
sns.lmplot(x='city-L/100km',
           y='price',
           data=df,
           fit_reg=False)

# %% [markdown]
# # **Question 5**
#
# Create a scatter plot comparing the price of cars with their highway mpg!

# %%
# using seaborn
sns.lmplot(x='highway-mpg',
           y='price',
           data=df,
           fit_reg=False,
           hue='body-style') # Color points based on body-style

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## Scatter plot

# %%
# add another variable to the scatterplot as hue
sns.lmplot(x='city-L/100km',
           y='price',
           data=df,
           fit_reg=False,
           hue='body-style')

# %%
# show a regression line
sns.lmplot(x='city-L/100km',
           y='price',
           data=df,
           hue='num-of-doors'
           , fit_reg=True
           )

# %% [markdown]
# ## Bubble Chart

# %%
# using seaborn
sns.relplot(x='city-L/100km',
            y='price',
            data=df,
            hue='body-style',
            size='curb-weight',   # adjust size for curb weight
            sizes=(20, 400), alpha=.5)

# %% [markdown]
# ## Heatmap

# %%
corr = df.select_dtypes(include=np.number).corr()
corr
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008153           0.055045    0.158018  0.123952
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075810           0.217300    0.371178  0.579795
# peak-rpm            0.279740           0.239543   -0.360305 -0.285970
# city-mpg           -0.035527          -0.225016   -0.470606 -0.665192
# highway-mpg         0.036233          -0.181877   -0.543304 -0.698142
# price              -0.082391           0.133999    0.584642  0.690628
# city-L/100km        0.066171           0.238567    0.476153  0.657373
# highway-L/100km    -0.029807           0.181189    0.577576  0.707108
#
#                       width    height  curb-weight  engine-size      bore  \
# symboling         -0.242423 -0.550160    -0.233118    -0.110581 -0.140019
# normalized-losses  0.086802 -0.373737     0.099404     0.112360 -0.029862
# wheel-base         0.814507  0.590742     0.782097     0.572027  0.493244
# length             0.857170  0.492063     0.880665     0.685025  0.608971
# width              1.000000  0.306002     0.866201     0.729436  0.544885
# height             0.306002  1.000000     0.307581     0.074694  0.180449
# curb-weight        0.866201  0.307581     1.000000     0.849072  0.644060
# engine-size        0.729436  0.074694     0.849072     1.000000  0.572609
# bore               0.544885  0.180449     0.644060     0.572609  1.000000
# stroke             0.188822 -0.060663     0.167438     0.205928 -0.055390
# compression-ratio  0.189867  0.259737     0.156433     0.028889  0.001263
# horsepower         0.615056 -0.087001     0.757981     0.822668  0.566903
# peak-rpm          -0.245800 -0.309974    -0.279361    -0.256733 -0.267392
# city-mpg          -0.633531 -0.049800    -0.749543    -0.650546 -0.582027
# highway-mpg       -0.680635 -0.104812    -0.794889    -0.679571 -0.591309
# price              0.751265  0.135486     0.834415     0.872335  0.543155
# city-L/100km       0.673363  0.003811     0.785353     0.745059  0.554610
# highway-L/100km    0.736728  0.084301     0.836921     0.783465  0.559112
#
#                      stroke  compression-ratio  horsepower  peak-rpm  \
# symboling         -0.008153          -0.182196    0.075810  0.279740
# normalized-losses  0.055045          -0.114713    0.217300  0.239543
# wheel-base         0.158018           0.250313    0.371178 -0.360305
# length             0.123952           0.159733    0.579795 -0.285970
# width              0.188822           0.189867    0.615056 -0.245800
# height            -0.060663           0.259737   -0.087001 -0.309974
# curb-weight        0.167438           0.156433    0.757981 -0.279361
# engine-size        0.205928           0.028889    0.822668 -0.256733
# bore              -0.055390           0.001263    0.566903 -0.267392
# stroke             1.000000           0.187871    0.098128 -0.063561
# compression-ratio  0.187871           1.000000   -0.214489 -0.435780
# horsepower         0.098128          -0.214489    1.000000  0.107884
# peak-rpm          -0.063561          -0.435780    0.107884  1.000000
# city-mpg          -0.033956           0.331425   -0.822192 -0.115413
# highway-mpg       -0.034636           0.268465   -0.804579 -0.058598
# price              0.082269           0.071107    0.809607 -0.101616
# city-L/100km       0.036133          -0.299372    0.889482  0.115830
# highway-L/100km    0.047089          -0.223361    0.840627  0.017694
#
#                    city-mpg  highway-mpg     price  city-L/100km  \
# symboling         -0.035527     0.036233 -0.082391      0.066171
# normalized-losses -0.225016    -0.181877  0.133999      0.238567
# wheel-base        -0.470606    -0.543304  0.584642      0.476153
# length            -0.665192    -0.698142  0.690628      0.657373
# width             -0.633531    -0.680635  0.751265      0.673363
# height            -0.049800    -0.104812  0.135486      0.003811
# curb-weight       -0.749543    -0.794889  0.834415      0.785353
# engine-size       -0.650546    -0.679571  0.872335      0.745059
# bore              -0.582027    -0.591309  0.543155      0.554610
# stroke            -0.033956    -0.034636  0.082269      0.036133
# compression-ratio  0.331425     0.268465  0.071107     -0.299372
# horsepower        -0.822192    -0.804579  0.809607      0.889482
# peak-rpm          -0.115413    -0.058598 -0.101616      0.115830
# city-mpg           1.000000     0.972044 -0.686571     -0.949713
# highway-mpg        0.972044     1.000000 -0.704692     -0.930028
# price             -0.686571    -0.704692  1.000000      0.789898
# city-L/100km      -0.949713    -0.930028  0.789898      1.000000
# highway-L/100km   -0.909024    -0.951100  0.801118      0.958306
#
#                    highway-L/100km
# symboling                -0.029807
# normalized-losses         0.181189
# wheel-base                0.577576
# length                    0.707108
# width                     0.736728
# height                    0.084301
# curb-weight               0.836921
# engine-size               0.783465
# bore                      0.559112
# stroke                    0.047089
# compression-ratio        -0.223361
# horsepower                0.840627
# peak-rpm                  0.017694
# city-mpg                 -0.909024
# highway-mpg              -0.951100
# price                     0.801118
# city-L/100km              0.958306
# highway-L/100km           1.000000

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
# sns.set(rc = {'figure.figsize':(15, 15)})
fig, ax = plt.subplots(figsize=(14, 14))

sns.heatmap(corr, annot=True
            , cmap="crest"
            )
# Out:
# <Axes: >

# %%
num_cols = ['horsepower', 'engine-size', 'curb-weight', 'city-mpg', 'city-L/100km', 'price']
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap="flare")
# Out:
# <Axes: >

# %% [markdown]
# # Word Cloud

# %%
# install wordcloud
# !conda install -c conda-forge wordcloud==1.4.1 --yes

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# /bin/bash: line 1: conda: command not found
# Wordcloud is installed and imported!

# %%
df.make.value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# subaru           12
# volkswagen       12
# volvo            11
# peugot           11
# dodge             9
# mercedes-benz     8
# bmw               8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# chevrolet         3
# alfa-romero       3
# jaguar            3
# isuzu             2
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
# combine all the brand values in the make column into a single string
text = ' '.join(df.make)

# generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white', collocations=False).generate(text)

# plot the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')   # remove axis
plt.show()

# %% [markdown]
# # Map

# %%
! pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from folium) (2.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2025.10.5)

# %%
! pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy) (2.1)

# %%
from geopy.geocoders import Nominatim

address = 'Bhutan'

# %%
geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Bhutan are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Bhutan are 27.549511, 90.5119273.

# %%
import folium

# %%
# create a map of Thimphu
# map = folium.Map(location=(27.4716, 89.6386)
#                 #  , tiles="Esri.WorldStreetMap"
#                  )

# create a map of Samtse
# map = folium.Map(location=(26.9131, 89.0836), tiles="Esri.WorldStreetMap")

# map

# %%
# get data (source: https://simplemaps.com/data/bt-cities)
path = "/content/drive/MyDrive/Data/bt.csv"

btdf = pd.read_csv(path)
btdf.head()
# Out:
#                city      lat      lng country iso2        admin_name  capital  \
# 0           Thimphu  27.4722  89.6361  Bhutan   BT           Thimphu  primary
# 1      Phuntsholing  26.8500  89.3833  Bhutan   BT           Chhukha      NaN
# 2              Paro  27.4333  89.4167  Bhutan   BT              Paro    admin
# 3        Geylegphug  26.8706  90.4856  Bhutan   BT           Sarpang      NaN
# 4  Samdrup Jongkhar  26.8000  91.5050  Bhutan   BT  Samdrup Jongkhar    admin
#
#    population  population_proper
# 0    114551.0           114551.0
# 1     27658.0            27658.0
# 2     11448.0            11448.0
# 3      9858.0             9858.0
# 4      9325.0             9325.0

# %%
max_pop = max(btdf.population_proper)
max_pop
# Out:
# 114551.0

# %%
# create a map of Bhutan using latitude and longitude values
map = folium.Map(location=[latitude, longitude],
                 zoom_start=9,
                 control_scale=True)

# add city markers to the map
for city, lat, lon, pop in zip(btdf['city'], btdf['lat'], btdf['lng'], btdf['population_proper']):
    label = 'City: {}, Population: {:,}'.format(city, pop)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=pop/max_pop * 100,
        tooltip=city,
        popup=label,
        color='cadetblue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50cb3642394eed9b1ccb6753f7f9d0f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50cb3642394eed9b1ccb6753f7f9d0f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50cb3642394eed9b1ccb6753f7f9d0f5 = L.map(
#                 &quot;map_50cb3642394eed9b1ccb6753f7f9d0f5&quot;,
#                 {
#                     center: [27.549511, 90.5119273],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_50cb3642394eed9b1ccb6753f7f9d0f5);
#
#
#
#
#
#             var tile_layer_d30cf8ff34c8c840c1f104277c929d0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d30cf8ff34c8c840c1f104277c929d0f.addTo(map_50cb3642394eed9b1ccb6753f7f9d0f5);
#
#
#             var circle_marker_0bd2f8a3ccdd78160fcf5a615e3bf59a = L.circleMarker(
#                 [27.4722, 89.6361],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cadetblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_50cb3642394eed9b1ccb6753f7f9d0f5);
#
#
#         var popup_6536d890eb435dc7e821382af978b3ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71d0cdca107253b3b092711f906ebe4a = $(`&lt;div id=&quot;html_71d0cdca107253b3b092711f906ebe4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Thimphu, Population: 114,551.0&lt;/div&gt;`)[0];
#                 popup_6536d890eb435dc7e821382af978b3ec.setContent(html_71d0cdca107253b3b092711f906ebe4a);
#
#
#
#         circle_marker_0bd2f8a3ccdd78160fcf5a615e3bf59a.bindPopup(popup_6536d890eb435dc7e821382af978b3ec)
#         ;
#
#
#
#
#             circle_marker_0bd2f8a3ccdd78160fcf5a615e3bf59a.bindTooltip(
#                 `&lt;div&gt;
#                      Thimphu
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_dd02a74f641e1887b4bf72d056663cd0 = L.circleMarker(
#                 [26.85, 89.3833],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cadetblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 24.14470410559489, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_50cb3642394eed9b1ccb6753f7f9d0f5);
#
#
#         var popup_851ec45c111e895f5b9808d75bcd9e54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_378c9218cc1048c86b723f4053d26a2a = $(`&lt;div id=&quot;html_378c9218cc1048c86b723f4053d26a2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City: Phuntsholing, Population: 27,658.0&lt;/div&gt;`)[0];
#                 popup_851ec45c111e895f5b9808d75bcd9e54.setContent(html_378c9218cc1048c86b723f4053d26a2a);
#
#
#
#         circle_marker_dd02a74f641e1887b4bf72d056663cd0.bindPopup(popup_851ec45c111e895f5b9808d75bcd9e54)
#         ;
#
#
#
#
#             circle_marker_dd02a74f641e1887b4bf72d056663cd0.bindTooltip(
#                 `&lt;div&gt;
#                      Phuntsholing
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_c4eaf8c73cfd46e9eea5a09d0464ae20 = L.circleMarker(
#                 [27.4333, 89.4167],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;cadetblue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.993801887368944, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_50cb3642394eed9b1ccb6753f7f9d0f5);
#
#
#         var popup_c68f3286e

# %% [markdown]
# # Colors

# %%
import math

import matplotlib.pyplot as plt

import matplotlib.colors as mcolors
from matplotlib.patches import Rectangle


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * ncols + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * ncols)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.BASE_COLORS, ncols=3, sort_colors=False)

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()
